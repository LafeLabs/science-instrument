# %%
import matplotlib.pyplot as plt
import numpy as np
import skrf as rf

# %%
caldata = rf.read_all()

# %%
caldata
# Out:
# {'ideal_port2_load': 1-Port Network: 'ideal_port2_load',  0.001-20.0 GHz, 10001 pts, z0=[50.+0.j]}
